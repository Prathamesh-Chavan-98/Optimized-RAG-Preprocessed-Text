# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathamesh-Chavan-98/Optimized-RAG-Preprocessed-Text/blob/main/_Optimized_RAG_Preprocessed_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain_community langchain_chroma
# !pip install pypdf
# !pip install -qU langchain-openai
# !pip install pymupdf
# !pip install --upgrade langchain
# !pip install sentence-transformers
# !pip install langchainhub
# !pip install langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 1.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.6/990.6 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 38.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.3/584.3 kB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 40.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.0/384.0 kB 22.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.2/140.2 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 14.9 MB/s eta 0:00:00
# ...

# %%
import getpass
import os
import fitz  # PyMuPDF
from langchain.document_loaders import TextLoader
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain import hub
from langchain_chroma import Chroma
from langchain_community.document_loaders import WebBaseLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import OpenAIEmbeddings
from langchain_community.document_loaders import PyPDFLoader
from langchain_openai import ChatOpenAI
from langchain.embeddings import SentenceTransformerEmbeddings
from getpass import getpass
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4

# Use the correct argument for bs_kwargs as a dictionary
loader = WebBaseLoader(
    web_path="https://medium.com/@priyanshujha649/a-complete-beginner-guide-to-data-preprocessing-7bc66cf2b110",
    bs_kwargs={'parse_only': bs4.SoupStrainer()}
)

# %%
text_documents = loader.load()
text_documents
# Out:
# [Document(metadata={'source': 'https://medium.com/@priyanshujha649/a-complete-beginner-guide-to-data-preprocessing-7bc66cf2b110', 'title': 'A Complete Beginner Guide to Data Preprocessing | by Priyanshu Jha | Aug, 2024 | Medium', 'description': 'This guide is for those who are new to the world of data science and data preprocessing. Let’s start by understanding what data preprocessing is. Data preprocessing is an essential step in…', 'language': 'en'}, page_content="A Complete Beginner Guide to Data Preprocessing | by Priyanshu Jha | Aug, 2024 | MediumOpen in appSign upSign inWriteSign upSign inA Complete Beginner Guide to Data PreprocessingPriyanshu Jha·Follow6 min read·Just now--ListenShareGenerated by Meta AIThis guide is for those who are new to the world of data science and data preprocessing. Let’s start by understanding what data preprocessing is.What is Data preprocessing?Data preprocessing is an essential step in exploratory data analysis (EDA). It involves transforming raw 
# ...

# %%
lowered_documents = [doc.page_content.lower() for doc in text_documents]

print(lowered_documents)
# Out:
# ["a complete beginner guide to data preprocessing | by priyanshu jha | aug, 2024 | mediumopen in appsign upsign inwritesign upsign ina complete beginner guide to data preprocessingpriyanshu jha·follow6 min read·just now--listensharegenerated by meta aithis guide is for those who are new to the world of data science and data preprocessing. let’s start by understanding what data preprocessing is.what is data preprocessing?data preprocessing is an essential step in exploratory data analysis (eda). it involves transforming raw data into a clean and complete format to enable further data analysis and application of various machine learning models.let’s take a closer look at the steps involved in data preprocessing.flowchart of data pre-processingdata collection and loading the dataset:if you can’t find the data you need on popular sources like kaggle, you can use alternative techniques to get it. for example, you can use an api to retrieve the data, or you can use web scraping to extract 
# ...

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude = string.punctuation
def remove_punc(text):
    return text.translate(str.maketrans('','',exclude))

# %%
for doc in lowered_documents:
    cleaned_text = remove_punc(doc)
    print(cleaned_text)
# Out:
# a complete beginner guide to data preprocessing  by priyanshu jha  aug 2024  mediumopen in appsign upsign inwritesign upsign ina complete beginner guide to data preprocessingpriyanshu jha·follow6 min read·just nowlistensharegenerated by meta aithis guide is for those who are new to the world of data science and data preprocessing let’s start by understanding what data preprocessing iswhat is data preprocessingdata preprocessing is an essential step in exploratory data analysis eda it involves transforming raw data into a clean and complete format to enable further data analysis and application of various machine learning modelslet’s take a closer look at the steps involved in data preprocessingflowchart of data preprocessingdata collection and loading the datasetif you can’t find the data you need on popular sources like kaggle you can use alternative techniques to get it for example you can use an api to retrieve the data or you can use web scraping to extract the data from websites
# ...

# %%
cleaned_text
# Out:
# 'a complete beginner guide to data preprocessing  by priyanshu jha  aug 2024  mediumopen in appsign upsign inwritesign upsign ina complete beginner guide to data preprocessingpriyanshu jha·follow6 min read·just nowlistensharegenerated by meta aithis guide is for those who are new to the world of data science and data preprocessing let’s start by understanding what data preprocessing iswhat is data preprocessingdata preprocessing is an essential step in exploratory data analysis eda it involves transforming raw data into a clean and complete format to enable further data analysis and application of various machine learning modelslet’s take a closer look at the steps involved in data preprocessingflowchart of data preprocessingdata collection and loading the datasetif you can’t find the data you need on popular sources like kaggle you can use alternative techniques to get it for example you can use an api to retrieve the data or you can use web scraping to extract the data from website
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download the stopwords dataset
nltk.download('stopwords')
nltk.download('punkt')

# Tokenize the text
words = word_tokenize(cleaned_text)

# Get the list of stopwords
stop_words = set(stopwords.words('english'))

# Remove stopwords
filtered_words = [word for word in words if word.lower() not in stop_words]

# Join the filtered words back into a string
filtered_text = ' '.join(filtered_words)

print(filtered_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %%
filtered_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-55d4df67ed38> in <cell line: 1>()
# ----> 1 filtered_text
#
# NameError: name 'filtered_text' is not defined

# %%
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass("Enter LangChain API Key: ")
os.environ["TOGETHER_API_KEY"] = getpass("Enter Together API Key: ")

# Load the LLM with Together API key
llm = ChatOpenAI(
    base_url="https://api.together.xyz/v1",
    api_key=os.environ["TOGETHER_API_KEY"],
    model="mistralai/Mixtral-8x7B-Instruct-v0.1",
)

docs = text_documents

# Split the document into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=300)
splits = text_splitter.split_documents(docs)

# Create embeddings using SentenceTransformer
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# Create a vector store (Chroma) from the document chunks
vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings)

# Create a retriever
retriever = vectorstore.as_retriever()

# Load a pre-built RAG prompt
prompt = hub.pull("rlm/rag-prompt")

# Helper function to format documents
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# Function to generate a response using RAG
def generate_rag_response(question):
    # Retrieve relevant documents
    relevant_docs = retriever.get_relevant_documents(question)

    if not relevant_docs:
        return "No relevant documents found."

    # Format the retrieved documents as context
    context = format_docs(relevant_docs)

    # Fill the prompt with retrieved context and the question
    formatted_prompt = prompt.format(context=context, question=question)

    # Get the response from the LLM
    response = llm(formatted_prompt)

    return response
# Out:
# Enter LangChain API Key: ··········
# Enter Together API Key: ··········
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...

# %%
def qa_interface():
    while True:
        # Prompt user to enter a question
        question = input("Enter your question (or type 'exit' to quit): ")

        if question.lower() == 'exit':
            print("Exiting the QA interface.")
            break

        # Generate response using the RAG pipeline
        response = generate_rag_response(question)

        # Display the answer
        print("\nAnswer:", response, "\n")

# Run the QA interface
qa_interface()
# Out:
# Enter your question (or type 'exit' to quit): Conclusion
#
# Answer: content=" The conclusion is not provided in the context. However, the context is about a beginner's guide to data preprocessing, which involves transforming raw data into a clean and complete format for further data analysis and machine learning models. It covers steps like data collection, handling missing or null values, and dealing with categorical values." response_metadata={'token_usage': {'completion_tokens': 68, 'prompt_tokens': 890, 'total_tokens': 958}, 'model_name': 'mistralai/mixtral-8x7b-instruct-v0.1', 'system_fingerprint': None, 'finish_reason': 'eos', 'logprobs': None} id='run-851c327b-7568-46ca-bc2e-e58baa0756c5-0' usage_metadata={'input_tokens': 890, 'output_tokens': 68, 'total_tokens': 958}
#
# Enter your question (or type 'exit' to quit): exit
# Exiting the QA interface.
